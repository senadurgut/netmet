# %%
import numpy as np, uproot, awkward as ak, matplotlib.pyplot as plt
import branches as branches
import math as math
from helpers import *

# %%
plot_rate('/Users/sena/grad_school/Research/netmet/files/n_10000/output_wo_netmet.root', title = 'l1_met_thresh = 80')
# Out:
# L1 MET Threshold:  80
# NET MET Threshold:  8
# L1 MET Fixed Rate:  0.03661971830985916

# %%
plot_efficiency('/Users/sena/grad_school/Research/netmet/nano_70.root', title= 'Efficiency with CALO-L2 calibrations')
# Out:
# eff_data:  [0, 0.0189, 0, 0.046, 0.0227, 0.1, 0, ..., nan, nan, nan, nan, nan, nan, nan]
# /Users/sena/anaconda3/envs/netmet2/lib/python3.10/site-packages/awkward/_nplikes/array_module.py:292: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
